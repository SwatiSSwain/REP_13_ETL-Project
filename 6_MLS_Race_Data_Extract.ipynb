# %% [markdown]
# # ETL Project - EXTRACTION
# ## Terrence Cummings
# Data: Race mix of Minneapolis neighborhoods scraped from mncompass.org

# %%
import pandas as pd
from bs4 import BeautifulSoup
import json
import requests
import pymongo
from splinter import Browser
from selenium import webdriver
import time
import sys
import os
import datetime
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_argument("--headless")

# %%
#Initialize list to hold neighborhood URL's and neighborhood names
nbhd_links_lst = []
nbhd_names_lst = []

#URL for the MSP neighborhoods page at MN Compass. This page contains all the links to the individual neighborhood pages.
msp_nbhds_url = 'http://www.mncompass.org/profiles/neighborhoods/minneapolis-saint-paul'

#Create Chrome web driver
driver = webdriver.Chrome(options=chrome_options)

#Send the webdriver to the link
driver.get(msp_nbhds_url)

#Extract an object containing all the neighborhood links. Uses Selenium Xpath.
nbhd_links = driver.find_elements_by_xpath('//*[@id="list"]/div/ul[2]/li[*]/a')

#Go through each Selenium item and extract the link for the neighborhood.
for nbhd in nbhd_links:
    href = nbhd.get_attribute('href')
    #Add the link to the list of neighborhood links
    nbhd_links_lst.append(href)
    #Extract the name of the neighborhood from the end of the URL and add to the list of neighborhood names.
    nbhd_names_lst.append(href[60:])

#Close the webdriver    
driver.close()

# %%
nbhd_links_df = pd.DataFrame(nbhd_links_lst, columns=["URL"])
nbhd_links_df.to_csv('nbhd_links.csv', index=False)
nbhd_links_lst
# Out:
# ['http://www.mncompass.org/profiles/neighborhoods/minneapolis/armatage',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/audubon-park',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/bancroft',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/cedar-isles-dean',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/cedar-riverside',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/central',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/como',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/cooper',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/corcoran',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/diamond-lake',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/downtown-west',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/ecco',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/east-harriet',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/east-isles',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/elliot-park',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/ericsson',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/folwell',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/fulton',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/hawthorne',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/hiawatha',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/holland',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/howe',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/jordan',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/kenny',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/king-field',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/lind-bohanon',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/linden-hills',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/longfellow',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/loring-park',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/lowry-hill',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/lowry-hill-east',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/lyndale',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/lynnhurst',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/marcy-holmes',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/midtown-phillips',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/minnehaha',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/near-north',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/north-loop',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/northrop',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/phillips-west',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/powderhorn-park',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/prospect-park-east-river-road',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/seward',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/sheridan',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/south-uptown',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/standish',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/stevens-square-loring-heights',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/tangletown',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/ventura-village',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/victory',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/waite-park',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/webber-camden',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/wenonah',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/whittier',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/willard-hay',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/windom',
#  'http://www.mncompass.org/profiles/neighborhoods/minneapolis/windom-park']

# %%
#Open the webdriver
driver = webdriver.Chrome(options=chrome_options)

#Initialize lists to hold the count and percentage for each race. The list is in the same order as the neighborhoods above.
white_cnt_lst = []
white_pct_lst = []
black_cnt_lst = []
black_pct_lst = []
native_cnt_lst = []
native_pct_lst = []
asian_cnt_lst = []
asian_pct_lst = []
other_cnt_lst = []
other_pct_lst = []
twoormore_cnt_lst = []
twoormore_pct_lst = []
hispanic_cnt_lst = []
hispanic_pct_lst = []
ofcolor_cnt_lst = []
ofcolor_pct_lst = []

#For each neighborhood
for nbhd_link in nbhd_links_lst:
    #Go to the link for the neighborhood
    driver.get(nbhd_link)
    #A short timer to give the browser time to respond
    time.sleep(1)
    #Use Selenium Xpath to extract the table list for the race, access the count and percent elements of the list and add to lists
    nbhd_white = driver.find_elements_by_xpath('//*[@id="totalWhite"]')
    white_cnt_lst.append(nbhd_white[0].text)
    white_pct_lst.append(nbhd_white[2].text)
    nbhd_black = driver.find_elements_by_xpath('//*[@id="totalBlack"]')
    black_cnt_lst.append(nbhd_black[0].text)
    black_pct_lst.append(nbhd_black[2].text)
    nbhd_native = driver.find_elements_by_xpath('//*[@id="totalNative"]')
    native_cnt_lst.append(nbhd_native[0].text)
    native_pct_lst.append(nbhd_native[2].text)
    nbhd_asian = driver.find_elements_by_xpath('//*[@id="totalAsian"]')
    asian_cnt_lst.append(nbhd_asian[0].text)
    asian_pct_lst.append(nbhd_asian[2].text)
    nbhd_other = driver.find_elements_by_xpath('//*[@id="totalOther"]')
    other_cnt_lst.append(nbhd_other[0].text)
    other_pct_lst.append(nbhd_other[2].text)
    nbhd_twoormore = driver.find_elements_by_xpath('//*[@id="twoOrMoreRaces"]')
    twoormore_cnt_lst.append(nbhd_twoormore[0].text)
    twoormore_pct_lst.append(nbhd_twoormore[2].text)
    nbhd_hispanic = driver.find_elements_by_xpath('//*[@id="totalHispanic"]')
    hispanic_cnt_lst.append(nbhd_hispanic[0].text)
    hispanic_pct_lst.append(nbhd_hispanic[2].text)
    nbhd_ofcolor = driver.find_elements_by_xpath('//*[@id="totalOfColor"]')
    ofcolor_cnt_lst.append(nbhd_ofcolor[0].text)
    ofcolor_pct_lst.append(nbhd_ofcolor[2].text)

#Close the browser
driver.close()

# %%
#Zip the lists together and make a final dataframe where each row is a neighborhood.
nbhd_race_df = pd.DataFrame(list(zip(nbhd_names_lst, white_cnt_lst, white_pct_lst, black_cnt_lst, black_pct_lst, native_cnt_lst, native_pct_lst, asian_cnt_lst, asian_pct_lst, other_cnt_lst, other_pct_lst, twoormore_cnt_lst, twoormore_pct_lst, hispanic_cnt_lst, hispanic_pct_lst, ofcolor_cnt_lst, ofcolor_pct_lst, nbhd_links_lst)), columns =['neighborhood', 'white_cnt', 'white_pct', 'black_cnt', 'black_pct', 'native_cnt', 'native_pct', 'asian_cnt', 'asian_pct', 'other_cnt', 'other_pct', 'two_or_more_cnt', 'two_or_more_pct', 'hispanic_cnt', 'hispanic_pct', 'of_color_cnt', 'of_color_pct', 'URL'])

# %%
nbhd_race_df.to_csv('nbhd_race.csv', index=False)
nbhd_race_df
# Out:
#                      neighborhood white_cnt white_pct   black_cnt black_pct  \
# 0                        armatage     4,316     84.5%  suppressed
# 1                    audubon-park     4,034     78.8%         386      7.5%
# 2                        bancroft     2,601     73.4%         413     11.6%
# 3                cedar-isles-dean     2,927     91.6%  suppressed
# 4                 cedar-riverside     3,219     32.0%       5,146     51.1%
# 5                         central     3,567     43.3%       2,116     25.7%
# 6                            como     4,314     72.2%         552      9.2%
# 7                          cooper     3,009     81.4%  suppressed
# 8                        corcoran     2,849     63.6%         760     17.0%
# 9                    diamond-lake     4,429     76.8%         651     11.3%
# 10                  downtown-west     4,854     60.1%       1,798     22.2%
# 11                           ecco
# 12                   east-harriet     3,106     86.1%  suppressed
# 13                     east-isles     3,334     88.9%  suppressed
# 14                    elliot-park     3,729     58.0%       1,975     30.7%
# 15                       ericsson     2,955     85.1%  suppressed
# 16                        folwell     1,873     32.6%       2,641     46.0%
# 17                         fulton     5,820     91.6%         147      2.3%
# 18                      hawthorne     1,028     21.8%       2,181     46.2%
# 19                       hiawatha     4,781     81.6%         608     10.4%
# 20                        holland     2,613     54.6%         725     15.1%
# 21                           howe     5,210     79.6%         731     11.2%
# 22                         jordan     1,505     17.5%       3,868     45.1%
# 23                          kenny     3,300     85.7%  suppressed
# 24                     king-field     6,239     82.7%         365      4.8%
# 25                   lind-bohanon     2,328     42.7%       1,523     28.0%
# 26                   linden-hills     6,981     90.4%  suppressed
# 27                     longfellow     3,263     64.5%         801     15.8%
# 28                    loring-park     6,619     73.4%       1,243     13.8%
# 29                     lowry-hill     3,285     84.3%         137      3.5%
# 30                lowry-hill-east     5,508     77.1%         952     13.3%
# 31                        lyndale     4,196     58.8%       1,530     21.4%
# 32                      lynnhurst     5,142     88.7%  suppressed
# 33                   marcy-holmes    10,640     76.2%         903      6.5%
# 34               midtown-phillips     2,105     39.6%       1,956     36.8%
# 35                      minnehaha     3,332     80.8%         399      9.7%
# 36                     near-north     1,115     15.4%       4,078     56.3%
# 37                     north-loop     4,704     76.3%         855     13.9%
# 38                       northrop     3,694     79.1%         364      7.8%
# 39                  phillips-west     1,437     26.3%       2,897     53.1%
# 40                powderhorn-park     5,586     56.4%       1,787     18.0%
# 41  prospect-park-east-river-road     9,432     67.2%       1,002      7.1%
# 42                         seward     4,137     52.7%       3,345     42.6%
# 43                       sheridan     2,215     72.9%         513     16.9%
# 44                   south-uptown     5,078     86.0%         267      4.5%
# 45                       standish     5,049     77.8%         472      7.3%
# 46  stevens-square-loring-heights     2,426     63.3%         856     22.3%
# 47                     tangletown     3,973     88.0%  suppressed
# 48                ventura-village     1,619     25.2%       3,303     51.4%
# 49                        victory     3,135     67.6%         874     18.9%
# 50                     waite-park     4,715     86.0%  suppressed
# 51                  webber-camden     2,386     43.9%       2,149     39.5%
# 52                        wenonah     3,246     72.9%         425      9.5%
# 53                       whittier     8,620     60.8%       3,327     23.5%
# 54                    willard-hay     2,695     27.6%       4,818     49.4%
# 55                         windom     3,870     73.9%         649     12.4%
# 56                    windom-park     4,488     82.4%         269      4.9%
#
#     native_cnt native_pct   asian_cnt asian_pct   other_cnt other_pct  \
# 0   suppressed             suppressed            suppressed
# 1   suppressed             suppressed            suppressed
# 2   suppressed                     74      2.1%  suppressed
# 3   suppressed             suppressed            suppressed
# 4   suppressed                  1,156     11.5%  suppressed
# 5   suppressed                    194      2.4%       1,738     21.1%
# 6   suppressed                    893     14.9%  suppressed
# 7   suppressed             suppressed            suppressed
# 8   suppressed                    115      2.6%         352      7.9%
# 9   suppressed             suppressed            suppressed
# 10         176       2.2%         908     11.2%  suppressed
# 11
# 12  suppressed             suppressed            suppressed
# 13  suppressed                    104      2.8%  suppressed
# 14          74       1.2%         366      5.7%  suppressed
# 15  suppressed                     96      2.8%  suppressed
# 16  suppressed                    912     15.9%  suppressed
# 17  suppressed                    155      2.4%  suppressed
# 18  suppressed                    875     18.5%         310      6.6%
# 19  suppressed                    187      3.2%  suppressed
# 20         225       4.7%  suppressed                   740     15.5%
# 21  suppressed                    161      2.5%         117      1.8%
# 22  suppressed                  1,759     20.5%         686      8.0%
# 23  suppressed             suppressed            suppressed
# 24  suppressed                    256      3.4%         328      4.3%
# 25  suppressed                    714     13.1%  suppressed
# 26  suppressed                    187      2.4%  suppressed
# 27  suppressed                    141      2.8%         410      8.1%
# 28  suppressed                    525      5.8%  suppressed
# 29  suppressed                    135      3.5%  suppressed
# 30  suppressed                    278      3.9%  suppressed
# 31  suppressed                    193      2.7%         740     10.4%
# 32  suppressed             suppressed            suppressed
# 33  suppressed                  1,372      9.8%  suppressed
# 34  suppressed                    220      4.1%         865     16.3%
# 35  suppressed                     61      1.5%  suppressed
# 36  suppressed                  1,121     15.5%         352      4.9%
# 37  suppressed                    242      3.9%  suppressed
# 38  suppressed                     50      1.1%  suppressed
# 39  suppressed             suppressed                   786     14.4%
# 40  suppressed                    124      1.3%       1,841     18.6%
# 41         100       0.7%       2,760     19.7%         125      0.9%
# 42          45       0.6%         137      1.7%  suppressed
# 43  suppressed             suppressed            suppressed
# 44  suppressed                    229      3.9%  suppressed
# 45  suppressed                    108      1.7%  suppressed
# 46  suppressed                    155      4.0%  suppressed
# 47  suppressed             suppressed            suppressed
# 48         386       6.0%  suppressed                   689     10.7%
# 49  suppressed             suppressed            suppressed
# 50  suppressed             suppressed            suppressed
# 51  suppressed                    389      7.2%  suppressed
# 52  suppressed                     75      1.7%         329      7.4%
# 53  suppressed                    477      3.4%       1,170      8.3%
# 54         204       2.1%       1,222     12.5%  suppressed
# 55  suppressed             suppressed            suppressed
# 56         143       2.6%         197      3.6%  suppressed
#
#    two_or_more_cnt two_or_more_pct hispanic_cnt hispanic_pct of_color_cnt  \
# 0              185            3.6%   suppressed                       792
# 1              303            5.9%          449         8.8%        1,083
# 2              278            7.8%          521        14.7%          943
# 3       suppressed                   suppressed                suppressed
# 4              396            3.9%          270         2.7%        6,846
# 5              513            6.2%        3,204        38.9%        4,670
# 6              106            1.8%          427         7.1%        1,663
# 7              113            3.1%   suppressed                       686
# 8              253            5.6%          920        20.6%        1,630
# 9       suppressed                          485         8.4%        1,335
# 10             306            3.8%          280         3.5%        3,229
# 11
# 12             211            5.8%          160         4.4%          500
# 13      suppressed                   suppressed                suppressed
# 14             158            2.5%          217         3.4%        2,700
# 15             131            3.8%          136         3.9%          517
# 16             252            4.4%          332         5.8%        3,869
# 17             182            2.9%           90         1.4%          535
# 18             173            3.7%          481        10.2%        3,689
# 19             235            4.0%          187         3.2%        1,075
# 20             381            8.0%          946        19.8%        2,172
# 21             294            4.5%          477         7.3%        1,336
# 22             730            8.5%        1,130        13.2%        7,080
# 23      suppressed                   suppressed                suppressed
# 24             333            4.4%          495         6.6%        1,304
# 25             808           14.8%          362         6.6%        3,120
# 26             263            3.4%   suppressed                       745
# 27             277            5.5%          880        17.4%        1,797
# 28             488            5.4%          573         6.4%        2,393
# 29             230            5.9%   suppressed                       611
# 30             267            3.7%          409         5.7%        1,632
# 31             419            5.9%        1,550        21.7%        2,938
# 32             227            3.9%          157         2.7%          655
# 33             629            4.5%          688         4.9%        3,329
# 34             146            2.7%        1,687        31.7%        3,214
# 35             285            6.9%   suppressed                       791
# 36             413            5.7%          578         8.0%        6,126
# 37             229            3.7%          260         4.2%        1,460
# 38             155            3.3%          311         6.7%          977
# 39             173            3.2%        1,077        19.7%        4,020
# 40             372            3.8%        3,244        32.7%        4,322
# 41             608            4.3%          355         2.5%        4,595
# 42             153            1.9%          127         1.6%        3,719
# 43             118            3.9%          301         9.9%          824
# 44             221            3.8%          243         4.1%          826
# 45             401            6.2%          713        11.0%        1,437
# 46             320            8.3%          256         6.7%        1,408
# 47      suppressed                          191         4.2%          539
# 48             321            5.0%        1,294        20.1%        4,812
# 49             273            5.9%   suppressed                     1,501
# 50             202            3.7%          345         6.3%          768
# 51             103            1.9%          520         9.6%        3,048
# 52             360            8.1%          438         9.8%        1,207
# 53             464            3.3%        2,009        14.2%        5,549
# 54             682            7.0%          905         9.3%        7,056
# 55      suppressed                          435         8.3%        1,366
# 56             190            3.5%          371         6.8%          957
#
#    of_color_pct                                                URL
# 0         15.5%  http://www.mncompass.org/profiles/neighborhood...
# 1         21.2%  http://www.mncompass.org/profiles/neighborhood...
# 2         26.6%  http://www.mncompass.org/profiles/neighborhood...
# 3                http://www.mncompass.org/profiles/neighborhood...
# 4         68.0%  http://www.mncompass.org/profiles/neighborhood...
# 5         56.7%  http://www.mncompass.org/profiles/neighborhood...
# 6         27.8%  http://www.mncompass.org/profiles/neighborhood...
# 7         18.6%  http://www.mncompass.org/profiles/neighborhood...
# 8         36.4%  http://www.mncompass.org/profiles/neighborhood...
# 9         23.2%  http://www.mncompass.org/profiles/neighborhood...
# 10        39.9%  http://www.mncompass.org/profiles/neighborhood...
# 11               http://www.mncompass.org/profiles/neighborhood...
# 12        13.9%  http://www.mncompass.org/profiles/neighborhood...
# 13               http://www.mncompass.org/profiles/neighborhood...
# 14        42.0%  http://www.mncompass.org/profiles/neighborhood...
# 15        14.9%  http://www.mncompass.org/profiles/neighborhood...
# 16        67.4%  http://www.mncompass.org/profiles/neighborhood...
# 17         8.4%  http://www.mncompass.org/profiles/neighborhood...
# 18        78.2%  http://www.mncompass.org/profiles/neighborhood...
# 19        18.4%  http://www.mncompass.org/profiles/neighborhood...
# 20        45.4%  http://www.mncompass.org/profiles/neighborhood...
# 21        20.4%  http://www.mncompass.org/profiles/neighborhood...
# 22        82.5%  http://www.mncompass.org/profiles/neighborhood...
# 23               http://www.mncompass.org/profiles/neighborhood...
# 24        17.3%  http://www.mncompass.org/profiles/neighborhood...
# 25        57.3%  http://www.mncompass.org/profiles/neighborhood...
# 26         9.6%  http://www.mncompass.org/profiles/neighborhood...
# 27        35.5%  http://www.mncompass.org/profiles/neighborhood...
# 28        26.6%  http://www.mncompass.org/profiles/neighborhood...
# 29        15.7%  http://www.mncompass.org/profiles/neighborhood...
# 30        22.9%  http://www.mncompass.org/profiles/neighborhood...
# 31        41.2%  http://www.mncompass.org/profiles/neighborhood...
# 32        11.3%  http://www.mncompass.org/profiles/neighborhood...
# 33        23.8%  http://www.mncompass.org/profiles/neighborhood...
# 34        60.4%  http://www.mncompass.org/profiles/neighborhood...
# 35        19.2%  http://www.mncompass.org/profiles/neighborhood...
# 36        84.6%  http://www.mncompass.org/profiles/neighborhood...
# 37        23.7%  http://www.mncompass.org/profiles/neighborhood...
# 38        20.9%  http://www.mncompass.org/profiles/neighborhood...
# 39        73.7%  http://www.mncompass.org/profiles/neighborhood...
# 40        43.6%  http://www.mncompass.org/profiles/neighborhood...
# 41        32.8%  http://www.mncompass.org/profiles/neighborhood...
# 42        47.3%  http://www.mncompass.org/profiles/neighborhood...
# 43        27.1%  http://www.mncompass.org/profiles/neighborhood...
# 44        14.0%  http://www.mncompass.org/profiles/neighborhood...
# 45        22.2%  http://www.mncompass.org/profiles/neighborhood...
# 46        36.7%  http://www.mncompass.org/profiles/neighborhood...
# 47        12.0%  http://www.mncompass.org/profiles/neighborhood...
# 48        74.8%  http://www.mncompass.org/profiles/neighborhood...
# 49        32.4%  http://www.mncompass.org/profiles/neighborhood...
# 50        14.0%  http://www.mncompass.org/profiles/neighborhood...
# 51        56.1%  http://www.mncompass.org/profiles/neighborhood...
# 52        27.1%  http://www.mncompass.org/profiles/neighborhood...
# 53        39.2%  http://www.mncompass.org/profiles/neighborhood...
# 54        72.4%  http://www.mncompass.org/profiles/neighborhood...
# 55        26.1%  http://www.mncompass.org/profiles/neighborhood...
# 56        17.6%  http://www.mncompass.org/profiles/neighborhood...

# %%
#Initialize list to hold community URL's and community names
cmnty_links_lst = []
cmnty_names_lst = []

#URL for the MSP community page at MN Compass. This page contains all the links to the individual community pages.
msp_cmnty_url = 'http://www.mncompass.org/profiles/neighborhoods/minneapolis-saint-paul'

#Create Chrome web driver
driver = webdriver.Chrome(options=chrome_options)

#Send the webdriver to the link
driver.get(msp_cmnty_url)

#Extract an object containing all the commumity links. Uses Selenium Xpath.
cmnty_links = driver.find_elements_by_xpath('//*[@id="list"]/div/ul[3]/li[*]/a')

#Go through each Selenium item and extract the link for the community.
for cmnty in cmnty_links:
    href = cmnty.get_attribute('href')
    #Add the link to the list of community links
    cmnty_links_lst.append(href)
    #Extract the name of the community from the end of the URL and add to the list of community names.
    cmnty_names_lst.append(href[58:])

#Close the webdriver    
driver.close()
cmnty_links_lst
# Out:
# ['http://www.mncompass.org/profiles/communities/minneapolis/calhoun-isles',
#  'http://www.mncompass.org/profiles/communities/minneapolis/camden',
#  'http://www.mncompass.org/profiles/communities/minneapolis/central',
#  'http://www.mncompass.org/profiles/communities/minneapolis/longfellow',
#  'http://www.mncompass.org/profiles/communities/minneapolis/near-north',
#  'http://www.mncompass.org/profiles/communities/minneapolis/nokomis',
#  'http://www.mncompass.org/profiles/communities/minneapolis/northeast',
#  'http://www.mncompass.org/profiles/communities/minneapolis/phillips',
#  'http://www.mncompass.org/profiles/communities/minneapolis/powderhorn',
#  'http://www.mncompass.org/profiles/communities/minneapolis/southwest',
#  'http://www.mncompass.org/profiles/communities/minneapolis/university']

# %%
cmnty_links_df = pd.DataFrame(cmnty_links_lst, columns=["URL"])
cmnty_links_df.to_csv('cmnty_links.csv', index=False)
cmnty_links_df
# Out:
#                                                   URL
# 0   http://www.mncompass.org/profiles/communities/...
# 1   http://www.mncompass.org/profiles/communities/...
# 2   http://www.mncompass.org/profiles/communities/...
# 3   http://www.mncompass.org/profiles/communities/...
# 4   http://www.mncompass.org/profiles/communities/...
# 5   http://www.mncompass.org/profiles/communities/...
# 6   http://www.mncompass.org/profiles/communities/...
# 7   http://www.mncompass.org/profiles/communities/...
# 8   http://www.mncompass.org/profiles/communities/...
# 9   http://www.mncompass.org/profiles/communities/...
# 10  http://www.mncompass.org/profiles/communities/...

# %%
#Open the webdriver
driver = webdriver.Chrome(options=chrome_options)

#Initialize lists to hold the count and percentage for each race. The list is in the same order as the neighborhoods above.
white_cnt_lst = []
white_pct_lst = []
black_cnt_lst = []
black_pct_lst = []
native_cnt_lst = []
native_pct_lst = []
asian_cnt_lst = []
asian_pct_lst = []
other_cnt_lst = []
other_pct_lst = []
twoormore_cnt_lst = []
twoormore_pct_lst = []
hispanic_cnt_lst = []
hispanic_pct_lst = []
ofcolor_cnt_lst = []
ofcolor_pct_lst = []

#For each community
for cmnty_link in cmnty_links_lst:
    #Go to the link for the neighborhood
    driver.get(cmnty_link)
    #A short timer to give the browser time to respond
    time.sleep(1)
    #Use Selenium Xpath to extract the table list for the race, access the count and percent elements of the list and add to lists
    white = driver.find_elements_by_xpath('//*[@id="totalWhite"]')
    white_cnt_lst.append(white[0].text)
    white_pct_lst.append(white[2].text)
    black = driver.find_elements_by_xpath('//*[@id="totalBlack"]')
    black_cnt_lst.append(black[0].text)
    black_pct_lst.append(black[2].text)
    native = driver.find_elements_by_xpath('//*[@id="totalNative"]')
    native_cnt_lst.append(native[0].text)
    native_pct_lst.append(native[2].text)
    asian = driver.find_elements_by_xpath('//*[@id="totalAsian"]')
    asian_cnt_lst.append(asian[0].text)
    asian_pct_lst.append(asian[2].text)
    other = driver.find_elements_by_xpath('//*[@id="totalOther"]')
    other_cnt_lst.append(other[0].text)
    other_pct_lst.append(other[2].text)
    twoormore = driver.find_elements_by_xpath('//*[@id="twoOrMoreRaces"]')
    twoormore_cnt_lst.append(twoormore[0].text)
    twoormore_pct_lst.append(twoormore[2].text)
    hispanic = driver.find_elements_by_xpath('//*[@id="totalHispanic"]')
    hispanic_cnt_lst.append(hispanic[0].text)
    hispanic_pct_lst.append(hispanic[2].text)
    ofcolor = driver.find_elements_by_xpath('//*[@id="totalOfColor"]')
    ofcolor_cnt_lst.append(ofcolor[0].text)
    ofcolor_pct_lst.append(ofcolor[2].text)

#Close the browser
driver.close()

# %%
#Zip the lists together and make a final dataframe where each row is a commumity.
cmnty_race_df = pd.DataFrame(list(zip(cmnty_names_lst, white_cnt_lst, white_pct_lst, black_cnt_lst, black_pct_lst, native_cnt_lst, native_pct_lst, asian_cnt_lst, asian_pct_lst, other_cnt_lst, other_pct_lst, twoormore_cnt_lst, twoormore_pct_lst, hispanic_cnt_lst, hispanic_pct_lst, ofcolor_cnt_lst, ofcolor_pct_lst, cmnty_links_lst)), columns =['community', 'white_cnt', 'white_pct', 'black_cnt', 'black_pct', 'native_cnt', 'native_pct', 'asian_cnt', 'asian_pct', 'other_cnt', 'other_pct', 'two_or_more_cnt', 'two_or_more_pct', 'hispanic_cnt', 'hispanic_pct', 'of_color_cnt', 'of_color_pct', 'URL'])

# %%
cmnty_race_df.to_csv('cmnty_race.csv', index=False)
cmnty_race_df
# Out:
#         community white_cnt white_pct black_cnt black_pct  native_cnt  \
# 0   calhoun-isles    27,911     86.1%     1,591      4.9%  suppressed
# 1          camden    13,565     44.1%    10,677     34.7%         343
# 2         central    23,384     66.2%     7,133     20.2%         405
# 3      longfellow    20,399     70.3%     5,521     19.0%         290
# 4      near-north     8,264     23.0%    17,163     47.9%         629
# 5         nokomis    30,885     79.6%     3,507      9.0%         629
# 6       northeast    28,051     74.9%     3,921     10.5%         674
# 7        phillips     6,310     28.6%     9,606     43.5%       1,255
# 8      powderhorn    33,738     59.0%    11,305     19.8%         787
# 9       southwest    42,747     86.0%     2,289      4.6%  suppressed
# 10     university    29,871     63.5%     7,760     16.5%         474
#
#    native_pct asian_cnt asian_pct other_cnt other_pct two_or_more_cnt  \
# 0                 1,080      3.3%       416      1.3%           1,309
# 1        1.1%     3,500     11.4%       691      2.2%           1,953
# 2        1.1%     2,410      6.8%       410      1.2%           1,564
# 3        1.0%       815      2.8%       901      3.1%           1,072
# 4        1.8%     5,493     15.3%     1,864      5.2%           2,448
# 5        1.6%       776      2.0%     1,214      3.1%           1,779
# 6        1.8%     1,035      2.8%     1,999      5.3%           1,793
# 7        5.7%       757      3.4%     3,400     15.4%             750
# 8        1.4%     1,387      2.4%     7,056     12.3%           2,876
# 9                 1,650      3.3%       959      1.9%           1,842
# 10       1.0%     6,578     14.0%       484      1.0%           1,870
#
#    two_or_more_pct hispanic_cnt hispanic_pct of_color_cnt of_color_pct  \
# 0             4.0%        1,166         3.6%        4,512        13.9%
# 1             6.4%        2,360         7.7%       17,164        55.9%
# 2             4.4%        1,645         4.7%       11,928        33.8%
# 3             3.7%        2,083         7.2%        8,613        29.7%
# 4             6.8%        3,784        10.5%       27,604        77.0%
# 5             4.6%        2,160         5.6%        7,905        20.4%
# 6             4.8%        3,989        10.6%        9,422        25.1%
# 7             3.4%        5,709        25.9%       15,768        71.4%
# 8             5.0%       13,036        22.8%       23,438        41.0%
# 9             3.7%        2,021         4.1%        6,986        14.0%
# 10            4.0%        1,849         3.9%       17,166        36.5%
#
#                                                   URL
# 0   http://www.mncompass.org/profiles/communities/...
# 1   http://www.mncompass.org/profiles/communities/...
# 2   http://www.mncompass.org/profiles/communities/...
# 3   http://www.mncompass.org/profiles/communities/...
# 4   http://www.mncompass.org/profiles/communities/...
# 5   http://www.mncompass.org/profiles/communities/...
# 6   http://www.mncompass.org/profiles/communities/...
# 7   http://www.mncompass.org/profiles/communities/...
# 8   http://www.mncompass.org/profiles/communities/...
# 9   http://www.mncompass.org/profiles/communities/...
# 10  http://www.mncompass.org/profiles/communities/...
