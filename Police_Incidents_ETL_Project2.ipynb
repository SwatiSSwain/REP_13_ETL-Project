# %%
import pandas as pd
import datetime
import numpy as np

# %% [markdown]
# # Import and Read CSVs

# %%
PI_2015 = ("source_files/Police_Incidents_2015.csv")
PI_2016 = ("source_files/Police_Incidents_2016.csv")
PI_2017 = ("source_files/Police_Incidents_2017.csv")
PI_2018 = ("source_files/Police_Incidents_2018.csv")
PI_2018_2019 = ("source_files/Police_Incidents_Last_2Years.csv")
Neigh_Key = ("target_files/MLS_Neighborhoods.csv")

# %%
PI_2015_df = pd.read_csv(PI_2015)
PI_2016_df = pd.read_csv(PI_2016)
PI_2017_df = pd.read_csv(PI_2017)
PI_2018_df = pd.read_csv(PI_2018)
PI_Last2Years_df = pd.read_csv(PI_2018_2019)
Neigh_Key_df = pd.read_csv(Neigh_Key)

# %% [markdown]
# # Merge Years of Police Incident Data

# %%
PI_pre18 = [PI_2015_df,PI_2016_df,PI_2017_df,PI_2018_df]
PI_pre18_merge = pd.concat(PI_pre18)
PI_pre18_merge.head(1)
# Out:
#    FID         PublicAddress  ControlNbr             CCN  Precinct  \
# 0    1  0021XX Broadway AV W     3363209  MP 2014 457317       4.0
#
#           ReportedDate            BeginDate      Time Offense  \
# 0  2015/01/01 00:04:59  2014/12/31 20:10:00  20:10:00  AUTOTH
#
#            Description  UCRCode          EnteredDate    GBSID        Lat  \
# 0  Motor Vehicle Theft        8  2015/01/01 00:05:21  15215.0  45.003096
#
#         Long                 X               Y Neighborhood  \
# 0 -93.307022  -10,386,890.1882  5,622,008.9491       JORDAN
#
#            LastChanged       LastUpdateDate
# 0  2015/01/01 01:33:55  2017/03/03 13:40:06

# %%
PI_pre18_final = PI_pre18_merge.drop(columns={"PublicAddress", "ControlNbr",
                                                 "BeginDate", "Time",
                                                 "EnteredDate", "GBSID","X", "Y",
                                                 "LastChanged", "LastUpdateDate",
                                                 "UCRCode","FID"})
PI_pre18_final.head(5)
# Out:
#               CCN  Precinct         ReportedDate Offense  \
# 0  MP 2014 457317       4.0  2015/01/01 00:04:59  AUTOTH
# 1  MP 2014 457574       4.0  2015/01/01 00:16:00  AUTOTH
# 2  MP 2015 999999       1.0  2015/01/01 01:13:52   THEFT
# 3  MP 2014 457244       4.0  2015/01/01 01:24:00   BURGD
# 4  MP 2015 000138       3.0  2015/01/01 01:40:00   BURGD
#
#             Description        Lat       Long   Neighborhood
# 0   Motor Vehicle Theft  45.003096 -93.307022         JORDAN
# 1   Motor Vehicle Theft  44.991960 -93.297170   NEAR - NORTH
# 2           Other Theft  44.982050 -93.273690  DOWNTOWN WEST
# 3  Burglary Of Dwelling  45.014000 -93.288020       MCKINLEY
# 4  Burglary Of Dwelling  44.902511 -93.258904   DIAMOND LAKE

# %%
PI_pre18_final = PI_pre18_final[["CCN","ReportedDate","Offense","Neighborhood","Precinct","Description","Lat","Long"]]
PI_pre18_final.head(5)
# Out:
#               CCN         ReportedDate Offense   Neighborhood  Precinct  \
# 0  MP 2014 457317  2015/01/01 00:04:59  AUTOTH         JORDAN       4.0
# 1  MP 2014 457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH       4.0
# 2  MP 2015 999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST       1.0
# 3  MP 2014 457244  2015/01/01 01:24:00   BURGD       MCKINLEY       4.0
# 4  MP 2015 000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE       3.0
#
#             Description        Lat       Long
# 0   Motor Vehicle Theft  45.003096 -93.307022
# 1   Motor Vehicle Theft  44.991960 -93.297170
# 2           Other Theft  44.982050 -93.273690
# 3  Burglary Of Dwelling  45.014000 -93.288020
# 4  Burglary Of Dwelling  44.902511 -93.258904

# %%
PI_Last2Years_df.head(2)
# Out:
#            X          Y        publicaddress            caseNumber precinct  \
# 0 -93.313506  44.924447     0027XX 43RD ST W  MP201818191203              5
# 1 -93.262572  44.958217  0024XX CHICAGO AVE   MP2018184309                3
#
#              reportedDate  reportedTime               beginDate  \
# 0  2018/06/10 00:00:00+00          1237  2018/06/10 00:00:00+00
# 1  2018/06/05 00:00:00+00           202  2018/06/05 00:00:00+00
#
#          reportedDateTime  beginTime  ...             enteredDate centergbsid  \
# 0  2018/06/10 17:37:00+00       1237  ...  2018/06/11 00:00:00+00     12543.0
# 1  2018/06/05 07:02:00+00         56  ...  2018/06/05 00:00:00+00     18932.0
#
#    centerLong  centerLat      centerX  centerY      neighborhood  \
# 0  -93.313511  44.924450  -10,387,612  5609635      Linden Hills
# 1  -93.262579  44.958222  -10,381,942  5614946  Midtown Phillips
#
#               lastchanged       LastUpdateDateETL OBJECTID
# 0  2018/06/12 00:00:00+00  2019/07/25 14:36:02+00        1
# 1  2018/06/05 00:00:00+00  2019/07/25 14:36:02+00        2
#
# [2 rows x 23 columns]

# %%
PI_Last2Years_final = PI_Last2Years_df.drop(columns={"publicaddress","reportedTime", "reportedDateTime",
                                                "beginDate", "beginTime",
                                                 "enteredDate", "X", "Y",
                                                 "lastchanged", "LastUpdateDateETL","enteredDate",
                                                 "centerX","centerY","centergbsid",
                                                 "enteredDate",
                                                 "OBJECTID", "UCRCode", "lastchanged","LastUpdateDateETL"})

PI_Last2Years_final.head(2)
# Out:
#              caseNumber precinct            reportedDate   offense  \
# 0  MP201818191203              5  2018/06/10 00:00:00+00  ARSON
# 1  MP2018184309                3  2018/06/05 00:00:00+00  THEFT
#
#                       description  centerLong  centerLat      neighborhood
# 0  ARSON                           -93.313511  44.924450      Linden Hills
# 1  OTHER THEFT                     -93.262579  44.958222  Midtown Phillips

# %%
PI_Last2Years_final = PI_Last2Years_final[['caseNumber','reportedDate','offense','neighborhood','precinct','description','centerLong','centerLat']]
PI_Last2Years_final.head(2)
# Out:
#              caseNumber            reportedDate   offense      neighborhood  \
# 0  MP201818191203        2018/06/10 00:00:00+00  ARSON         Linden Hills
# 1  MP2018184309          2018/06/05 00:00:00+00  THEFT     Midtown Phillips
#
#   precinct                     description  centerLong  centerLat
# 0        5  ARSON                           -93.313511  44.924450
# 1        3  OTHER THEFT                     -93.262579  44.958222

# %%
PI_pre18_final = PI_pre18_final.rename(columns={"CCN":"caseNumber", "ReportedDate":"reportedDate","Offense":"offense","Neighborhood":"neighborhood","Precinct":"precinct","Description":"description"})
PI_Last2Years_final = PI_Last2Years_final.rename(columns={"centerLong":"Long","centerLat":"Lat"})

# %%
yearjoins = [PI_pre18_final,PI_Last2Years_final]
PI_Final = pd.concat(yearjoins)
PI_Final.head(5)
# Out:
#        caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP 2014 457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP 2014 457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP 2015 999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP 2014 457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP 2015 000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long
# 0   Motor Vehicle Theft  45.003096 -93.307022
# 1   Motor Vehicle Theft  44.991960 -93.297170
# 2           Other Theft  44.982050 -93.273690
# 3  Burglary Of Dwelling  45.014000 -93.288020
# 4  Burglary Of Dwelling  44.902511 -93.258904

# %%
PI_Final['caseNumber'] = PI_Final['caseNumber'].str.replace(" ","")
PI_Final.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long
# 0   Motor Vehicle Theft  45.003096 -93.307022
# 1   Motor Vehicle Theft  44.991960 -93.297170
# 2           Other Theft  44.982050 -93.273690
# 3  Burglary Of Dwelling  45.014000 -93.288020
# 4  Burglary Of Dwelling  44.902511 -93.258904

# %%
incident_id = PI_Final.index + 1

# %%
PI_Final['incident_id']= incident_id

# %%
PI_Final['neighborhood'].isnull().sum(axis = 0)
# Out:
# 532

# %%
PI_Final = PI_Final.dropna(subset=['neighborhood'])

# %%
#PI_Final['neighborhood'].isnull().sum(axis = 0)

# %%
PI_Final.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long  incident_id
# 0   Motor Vehicle Theft  45.003096 -93.307022            1
# 1   Motor Vehicle Theft  44.991960 -93.297170            2
# 2           Other Theft  44.982050 -93.273690            3
# 3  Burglary Of Dwelling  45.014000 -93.288020            4
# 4  Burglary Of Dwelling  44.902511 -93.258904            5

# %% [markdown]
# # Change neighborhood names for joining with key table

# %%
PI_Final['neighborhood']= PI_Final['neighborhood'].str.upper()

# %%
PI_Final = PI_Final.replace(to_replace = "ST. ANTHONY WEST", value ="ST ANTHONY WEST")
PI_Final = PI_Final.replace(to_replace = "ST. ANTHONY EAST", value ="ST ANTHONY EAST")
PI_Final = PI_Final.replace(to_replace = "HUMBOLDT INDUSTRIAL AREA", value ="HUMBOLDT INDUST AREA")
PI_Final = PI_Final.replace(to_replace = "CAMDEN INDUSTRIAL", value ="CAMDEN INDUSTRIAL AREA")        
PI_Final = PI_Final.replace(to_replace = "CARAG", value ="South Uptown")
PI_Final = PI_Final.replace(to_replace = "BRYN - MAWR", value ="Bryn Mawr")
PI_Final = PI_Final.replace(to_replace = "COLUMBIA PARK", value ="Columbia")
PI_Final = PI_Final.replace(to_replace = "MID - CITY INDUSTRIAL", value ="Mid City Industrial Ar")
PI_Final = PI_Final.replace(to_replace = "NICOLLET ISLAND - EAST BANK", value ="Nicollet Is/East Bank")
PI_Final = PI_Final.replace(to_replace = "UNIVERSITY OF MINNESOTA", value ="University")
PI_Final = PI_Final.replace(to_replace = "STEVENS SQUARE - LORING HEIGHTS", value ="Steven's Square - Loring Heights")
PI_Final['neighborhood']= PI_Final['neighborhood'].str.upper()

PI_Final.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long  incident_id
# 0   Motor Vehicle Theft  45.003096 -93.307022            1
# 1   Motor Vehicle Theft  44.991960 -93.297170            2
# 2           Other Theft  44.982050 -93.273690            3
# 3  Burglary Of Dwelling  45.014000 -93.288020            4
# 4  Burglary Of Dwelling  44.902511 -93.258904            5

# %%
Neigh_Key_df['name']=Neigh_Key_df['name'].str.upper()
Neigh_Key_df = Neigh_Key_df.rename(columns={'name':"neighborhood"})
Neigh_Key_df.head(5)
# Out:
#    neighborhood_id  neighborhood  community_id
# 0                1      ARMATAGE            10
# 1                2  EAST HARRIET            10
# 2                3        FULTON            10
# 3                4         KENNY            10
# 4                5    KING FIELD            10

# %%
PI_Final['neighborhood'].isnull().sum(axis = 0)
# Out:
# 0

# %%
len(PI_Final)
# Out:
# 112709

# %% [markdown]
# # Join with key table

# %%
PI_Final_ID = pd.merge(PI_Final, Neigh_Key_df, on='neighborhood', how= 'left')
PI_Final_ID.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long  incident_id  neighborhood_id  \
# 0   Motor Vehicle Theft  45.003096 -93.307022            1               84
# 1   Motor Vehicle Theft  44.991960 -93.297170            2               85
# 2           Other Theft  44.982050 -93.273690            3               73
# 3  Burglary Of Dwelling  45.014000 -93.288020            4               45
# 4  Burglary Of Dwelling  44.902511 -93.258904            5               61
#
#    community_id
# 0             5
# 1             5
# 2             3
# 3             2
# 4             6

# %%
PI_Final_ID.dtypes
# Out:
# caseNumber          object
# reportedDate        object
# offense             object
# neighborhood        object
# precinct            object
# description         object
# Lat                float64
# Long               float64
# incident_id          int64
# neighborhood_id      int64
# community_id         int64
# dtype: object

# %%
PI_Final_ID['neighborhood_id'] = PI_Final_ID['neighborhood_id'].values.astype(np.int64)
PI_Final_ID['community_id'] = PI_Final_ID['community_id'].values.astype(np.int64)
PI_Final_ID.dtypes
# Out:
# caseNumber          object
# reportedDate        object
# offense             object
# neighborhood        object
# precinct            object
# description         object
# Lat                float64
# Long               float64
# incident_id          int64
# neighborhood_id      int64
# community_id         int64
# dtype: object

# %%
PI_Final_ID.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long  incident_id  neighborhood_id  \
# 0   Motor Vehicle Theft  45.003096 -93.307022            1               84
# 1   Motor Vehicle Theft  44.991960 -93.297170            2               85
# 2           Other Theft  44.982050 -93.273690            3               73
# 3  Burglary Of Dwelling  45.014000 -93.288020            4               45
# 4  Burglary Of Dwelling  44.902511 -93.258904            5               61
#
#    community_id
# 0             5
# 1             5
# 2             3
# 3             2
# 4             6

# %%
#QA Merging
#len(PI_Final_ID['neighborhood_id'])
#PI_Final_ID['neighborhood_id'].count()
#PI_Final_ID['neighborhood_id'].isnull().sum(axis = 0)

# %%
#QA Neighborhood Names
#a = PI_Final['neighborhood'].unique()
#a_df = pd.DataFrame(data=a)
#a_df 
#a_df.to_csv("target_files/neighborhoods.csv", index=False, header=True)

# %%
PI_Final_ID.head(5)
# Out:
#      caseNumber         reportedDate offense   neighborhood precinct  \
# 0  MP2014457317  2015/01/01 00:04:59  AUTOTH         JORDAN        4
# 1  MP2014457574  2015/01/01 00:16:00  AUTOTH   NEAR - NORTH        4
# 2  MP2015999999  2015/01/01 01:13:52   THEFT  DOWNTOWN WEST        1
# 3  MP2014457244  2015/01/01 01:24:00   BURGD       MCKINLEY        4
# 4  MP2015000138  2015/01/01 01:40:00   BURGD   DIAMOND LAKE        3
#
#             description        Lat       Long  incident_id  neighborhood_id  \
# 0   Motor Vehicle Theft  45.003096 -93.307022            1               84
# 1   Motor Vehicle Theft  44.991960 -93.297170            2               85
# 2           Other Theft  44.982050 -93.273690            3               73
# 3  Burglary Of Dwelling  45.014000 -93.288020            4               45
# 4  Burglary Of Dwelling  44.902511 -93.258904            5               61
#
#    community_id
# 0             5
# 1             5
# 2             3
# 3             2
# 4             6

# %% [markdown]
# # Export CSV

# %%
PI_Final_ID.to_csv("target_files/Police_Incidents.csv", index=False, header=True)
