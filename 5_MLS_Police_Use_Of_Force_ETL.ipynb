# %% [markdown]
# # Police Use Of Force Script

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import datetime as dt
import numpy as np


import psycopg2

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Group_Project')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-0d7c1521c578> in <module>
#       1 engine = create_engine('postgresql://postgres:postgres@localhost:5432/Group_Project')
# ----> 2 connection = engine.connect()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2216         """
#    2217
# -> 2218         return self._connection_cls(self, **kwargs)
#    2219
#    2220     @util.deprecated(
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2316         """
#    2317         return self._wrap_pool_connect(
# -> 2318             self.pool.unique_connection, _connection
#    2319         )
#    2320
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2287             if connection is None:
#    2288                 Connection._handle_dbapi_exception_noconnection(
# -> 2289                     e, dialect, self
#    2290                 )
#    2291             else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1553         elif should_wrap:
#    1554             util.raise_(
# -> 1555                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1556             )
#    1557         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2283         dialect = self.dialect
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#    2287             if connection is None:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655         except Exception as e:
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#     659             if first_connect_check:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#     492     def create_connect_args(self, url):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ## Load Source Data CSV

# %%
#load csv into dataframe
load_csv = ("source_files/Police_Use_of_Force_Source_Data.csv")

# %% [markdown]
# ## Read In Source Data CSV
# #### Produce Head Of DataFrame

# %%
source_data_df = pd.read_csv(load_csv)
source_data_df.head()
# Out:
#            X          Y  PoliceUseOfForceID CaseNumber  \
# 0 -93.291183  45.018526            11224233  08-005343
# 1 -93.265782  44.943185            11224234  08-010291
# 2 -93.268029  44.979702            11224235  08-024156
# 3 -93.271954  44.982469            11224236  08-025819
# 4 -93.277025  44.978019            11224237  08-039928
#
#              ResponseDate                   Problem Is911Call PrimaryOffense  \
# 0  2008/01/05 22:57:23+00        Suspicious Person         No         FLEEFT
# 1  2008/01/10 22:21:53+00      Motor Vehicle Chase         No           FLEE
# 2  2008/01/25 18:04:32+00              Disturbance         No         DISCON
# 3  2008/01/27 02:44:26+00              Disturbance         No         DISCON
# 4  2008/02/10 04:54:24+00  Traffic Law Enforcement         No           FLEE
#
#   SubjectInjury  ForceReportNumber  ... TotalCityCallsForYear  \
# 0           Yes                  1  ...                322402
# 1           Yes                  1  ...                322402
# 2            No                  1  ...                322402
# 3           NaN                  1  ...                322402
# 4           Yes                  3  ...                322402
#
#    TotalPrecinctCallsForYear TotalNeighborhoodCallsForYear CenterGBSID  \
# 0                    80434.0                          4226       18266
# 1                    84018.0                         10923       11907
# 2                    46998.0                         23458       18612
# 3                    46998.0                         23458       17873
# 4                    46998.0                         23458       25506
#
#   CenterLatitude CenterLongitude      CenterX      CenterY  \
# 0      45.018526      -93.291183 -10385126.96  5624438.454
# 1      44.943185      -93.265782 -10382299.34  5612581.534
# 2      44.979702      -93.268029 -10382549.52  5618326.520
# 3      44.982469      -93.271954 -10382986.45  5618762.022
# 4      44.978019      -93.277025 -10383550.97  5618061.726
#
#                 DateAdded OBJECTID
# 0  2020/06/02 08:18:33+00        1
# 1  2020/06/02 08:18:33+00        2
# 2  2020/06/02 08:18:33+00        3
# 3  2020/06/02 08:18:33+00        4
# 4  2020/06/02 08:18:33+00        5
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Drop Unwanted Fields From DataFrame
# #### Produce Head Of DataFrame

# %%
edited_source_data_df = source_data_df.drop(columns = {"X", "Y", "Is911Call", "ForceReportNumber",
                                  "SubjectRoleNumber", "TotalCityCallsForYear",
                                  "TotalPrecinctCallsForYear", "TotalNeighborhoodCallsForYear",
                                  "CenterGBSID", "CenterLatitude", "CenterLongitude",
                                  "CenterX", "CenterY", "DateAdded", "OBJECTID"})

edited_source_data_df.head(5)
# Out:
#    PoliceUseOfForceID CaseNumber            ResponseDate  \
# 0            11224233  08-005343  2008/01/05 22:57:23+00
# 1            11224234  08-010291  2008/01/10 22:21:53+00
# 2            11224235  08-024156  2008/01/25 18:04:32+00
# 3            11224236  08-025819  2008/01/27 02:44:26+00
# 4            11224237  08-039928  2008/02/10 04:54:24+00
#
#                     Problem PrimaryOffense SubjectInjury SubjectRole  \
# 0        Suspicious Person          FLEEFT           Yes           A
# 1      Motor Vehicle Chase            FLEE           Yes           A
# 2              Disturbance          DISCON            No           A
# 3              Disturbance          DISCON           NaN           A
# 4  Traffic Law Enforcement            FLEE           Yes           A
#
#            ForceType     ForceTypeAction   Race   Sex  EventAge  \
# 0       Bodily Force             Punches  Black  Male      29.0
# 1       Bodily Force             Punches  White  Male      22.0
# 2              Taser        Firing Darts  Black  Male      40.0
# 3  Chemical Irritant  Crowd Control Mace  Black  Male      29.0
# 4       Bodily Force               Knees  Black  Male      28.0
#
#       TypeOfResistance Precinct   Neighborhood
# 0         Fled on Foot        4       McKinley
# 1      Fled in Vehicle        3        Central
# 2  Commission of Crime        1  Downtown West
# 3  Commission of Crime        1  Downtown West
# 4      Fled in Vehicle        1  Downtown West

# %% [markdown]
# ## Rename Fields To Match ERD
# #### Produce Head Of DataFrame

# %%
renamed_columns_df = edited_source_data_df.rename(columns={'PoliceUseOfForceID': 'police_use_of_force_id',
                                                          'CaseNumber': 'case_number', 'ResponseDate': 'response_date',
                                                          'PrimaryOffense': 'primary_offense', 'SubjectInjury': 'subject_injury',
                                                          'SubjectRole': 'subject_role', 'ForceType': 'police_use_of_force_type',
                                                          'ForceTypeAction': 'force_type_action', 'Race': 'subject_race', 
                                                          'Sex': 'subject_sex', 'EventAge': 'subject_age', 'TypeOfResistance': 'type_of_resistance',
                                                          'Problem': 'problem', 'Precinct': 'precinct', 'Neighborhood': 'neighborhood'})

renamed_columns_df.head(5)
# Out:
#    police_use_of_force_id case_number           response_date  \
# 0                11224233   08-005343  2008/01/05 22:57:23+00
# 1                11224234   08-010291  2008/01/10 22:21:53+00
# 2                11224235   08-024156  2008/01/25 18:04:32+00
# 3                11224236   08-025819  2008/01/27 02:44:26+00
# 4                11224237   08-039928  2008/02/10 04:54:24+00
#
#                     problem primary_offense subject_injury subject_role  \
# 0        Suspicious Person           FLEEFT            Yes            A
# 1      Motor Vehicle Chase             FLEE            Yes            A
# 2              Disturbance           DISCON             No            A
# 3              Disturbance           DISCON            NaN            A
# 4  Traffic Law Enforcement             FLEE            Yes            A
#
#   police_use_of_force_type   force_type_action subject_race subject_sex  \
# 0             Bodily Force             Punches        Black        Male
# 1             Bodily Force             Punches        White        Male
# 2                    Taser        Firing Darts        Black        Male
# 3        Chemical Irritant  Crowd Control Mace        Black        Male
# 4             Bodily Force               Knees        Black        Male
#
#    subject_age   type_of_resistance precinct   neighborhood
# 0         29.0         Fled on Foot        4       McKinley
# 1         22.0      Fled in Vehicle        3        Central
# 2         40.0  Commission of Crime        1  Downtown West
# 3         29.0  Commission of Crime        1  Downtown West
# 4         28.0      Fled in Vehicle        1  Downtown West

# %% [markdown]
# ## Check If response_date is datetime

# %%
# Use .dtypes to figure out if response_date is datetime
renamed_columns_df.dtypes
# Out:
# police_use_of_force_id        int64
# case_number                  object
# response_date                object
# problem                      object
# primary_offense              object
# subject_injury               object
# subject_role                 object
# police_use_of_force_type     object
# force_type_action            object
# subject_race                 object
# subject_sex                  object
# subject_age                 float64
# type_of_resistance           object
# precinct                     object
# neighborhood                 object
# dtype: object

# %% [markdown]
# ## Change Values In response_date Field To datetime

# %%
# Convert response_date field to datetime via astype function 
renamed_columns_df['response_date'] = renamed_columns_df['response_date'].astype(np.datetime64)

# %% [markdown]
# ## Verify Values Changed In response_date Field

# %%
# Use .dtypes to figure out if response_date is now datetime
renamed_columns_df.dtypes
# Out:
# police_use_of_force_id               int64
# case_number                         object
# response_date               datetime64[ns]
# problem                             object
# primary_offense                     object
# subject_injury                      object
# subject_role                        object
# police_use_of_force_type            object
# force_type_action                   object
# subject_race                        object
# subject_sex                         object
# subject_age                        float64
# type_of_resistance                  object
# precinct                            object
# neighborhood                        object
# dtype: object

# %% [markdown]
# ## Load MLS_Neighborhood.csv

# %%
# Load and read in MLS_Neighborhood.csv
load_second_csv = ("target_files/MLS_Neighborhoods.csv")
nbhd_keys_df = pd.read_csv(load_second_csv)
nbhd_keys_df.head(5)
# Out:
#    neighborhood_id          name  community_id
# 0                1      Armatage            10
# 1                2  East Harriet            10
# 2                3        Fulton            10
# 3                4         Kenny            10
# 4                5    King Field            10

# %% [markdown]
# ## Change Field Name From New DataFrame To Match First DataFrame

# %%
# Use rename function to change the field name that is name to neighborhood.
nbhd_keys_df_edited = nbhd_keys_df.rename(columns= ({'name': 'neighborhood'}))

# %%
# Verify field name changed to neighborhood
nbhd_keys_df_edited.head(5)
# Out:
#    neighborhood_id  neighborhood  community_id
# 0                1      Armatage            10
# 1                2  East Harriet            10
# 2                3        Fulton            10
# 3                4         Kenny            10
# 4                5    King Field            10

# %% [markdown]
# ## Adjust Punctuation And Spelling Of Neighborhood Name From First DB To Match New DF

# %%
# Use replace function to change the name of the ten neighborhoods in the first DF that don't match the second DF
renamed_columns_df = renamed_columns_df.replace(to_replace = "St. Anthony West", value ="St Anthony West")
renamed_columns_df = renamed_columns_df.replace(to_replace = "St. Anthony East", value ="St Anthony East")
renamed_columns_df = renamed_columns_df.replace(to_replace = "Humboldt Industrial Area", value ="Humboldt Indust Area")
renamed_columns_df = renamed_columns_df.replace(to_replace = "CARAG", value ="South Uptown")
renamed_columns_df = renamed_columns_df.replace(to_replace = "Bryn - Mawr", value ="Bryn Mawr")
renamed_columns_df = renamed_columns_df.replace(to_replace = "Columbia Park", value ="Columbia")
renamed_columns_df = renamed_columns_df.replace(to_replace = "Mid - City Industrial", value ="Mid City Industrial Ar")
renamed_columns_df = renamed_columns_df.replace(to_replace = "Nicollet Island - East Bank", value ="Nicollet Is/East Bank")
renamed_columns_df = renamed_columns_df.replace(to_replace = "University of Minnesota", value ="University")
renamed_columns_df = renamed_columns_df.replace(to_replace = "McKinley", value ="Mckinley")

# %%
# Produce DF to verify neighborhood names have been changed.
renamed_columns_df
# Out:
#        police_use_of_force_id              case_number       response_date  \
# 0                    11224233                08-005343 2008-01-05 22:57:23
# 1                    11224234                08-010291 2008-01-10 22:21:53
# 2                    11224235                08-024156 2008-01-25 18:04:32
# 3                    11224236                08-025819 2008-01-27 02:44:26
# 4                    11224237                08-039928 2008-02-10 04:54:24
# ...                       ...                      ...                 ...
# 30049                11254282             20-Lynnhurst 2020-01-01 00:00:00
# 30050                11254283      12-St. Anthony East 2012-01-01 00:00:00
# 30051                11254284         19-Columbia Park 2019-01-01 00:00:00
# 30052                11254285               19-Kenwood 2019-01-01 00:00:00
# 30053                11254286  12-Cedar - Isles - Dean 2012-01-01 00:00:00
#
#                         problem primary_offense subject_injury subject_role  \
# 0            Suspicious Person           FLEEFT            Yes            A
# 1          Motor Vehicle Chase             FLEE            Yes            A
# 2                  Disturbance           DISCON             No            A
# 3                  Disturbance           DISCON            NaN            A
# 4      Traffic Law Enforcement             FLEE            Yes            A
# ...                         ...             ...            ...          ...
# 30049                       NaN             NaN            NaN          NaN
# 30050                       NaN             NaN            NaN          NaN
# 30051                       NaN             NaN            NaN          NaN
# 30052                       NaN             NaN            NaN          NaN
# 30053                       NaN             NaN            NaN          NaN
#
#       police_use_of_force_type   force_type_action subject_race subject_sex  \
# 0                 Bodily Force             Punches        Black        Male
# 1                 Bodily Force             Punches        White        Male
# 2                        Taser        Firing Darts        Black        Male
# 3            Chemical Irritant  Crowd Control Mace        Black        Male
# 4                 Bodily Force               Knees        Black        Male
# ...                        ...                 ...          ...         ...
# 30049                      NaN                   0          NaN         NaN
# 30050                      NaN                   0          NaN         NaN
# 30051                      NaN                   0          NaN         NaN
# 30052                      NaN                   0          NaN         NaN
# 30053                      NaN                   0          NaN         NaN
#
#        subject_age   type_of_resistance precinct          neighborhood
# 0             29.0         Fled on Foot        4              Mckinley
# 1             22.0      Fled in Vehicle        3               Central
# 2             40.0  Commission of Crime        1         Downtown West
# 3             29.0  Commission of Crime        1         Downtown West
# 4             28.0      Fled in Vehicle        1         Downtown West
# ...            ...                  ...      ...                   ...
# 30049          NaN                  NaN      NaN             Lynnhurst
# 30050          NaN                  NaN      NaN       St Anthony East
# 30051          NaN                  NaN      NaN              Columbia
# 30052          NaN                  NaN      NaN               Kenwood
# 30053          NaN                  NaN      NaN  Cedar - Isles - Dean
#
# [30054 rows x 15 columns]

# %% [markdown]
# ## Merge The Two DataFrames

# %%
# Use the merge function to merge the two DataFrames and produce head.
merged_df_x = pd.merge(renamed_columns_df, nbhd_keys_df_edited, on='neighborhood', how= 'left')
merged_df_x.head(5)
# Out:
#    police_use_of_force_id case_number       response_date  \
# 0                11224233   08-005343 2008-01-05 22:57:23
# 1                11224234   08-010291 2008-01-10 22:21:53
# 2                11224235   08-024156 2008-01-25 18:04:32
# 3                11224236   08-025819 2008-01-27 02:44:26
# 4                11224237   08-039928 2008-02-10 04:54:24
#
#                     problem primary_offense subject_injury subject_role  \
# 0        Suspicious Person           FLEEFT            Yes            A
# 1      Motor Vehicle Chase             FLEE            Yes            A
# 2              Disturbance           DISCON             No            A
# 3              Disturbance           DISCON            NaN            A
# 4  Traffic Law Enforcement             FLEE            Yes            A
#
#   police_use_of_force_type   force_type_action subject_race subject_sex  \
# 0             Bodily Force             Punches        Black        Male
# 1             Bodily Force             Punches        White        Male
# 2                    Taser        Firing Darts        Black        Male
# 3        Chemical Irritant  Crowd Control Mace        Black        Male
# 4             Bodily Force               Knees        Black        Male
#
#    subject_age   type_of_resistance precinct   neighborhood  neighborhood_id  \
# 0         29.0         Fled on Foot        4       Mckinley             45.0
# 1         22.0      Fled in Vehicle        3        Central             25.0
# 2         40.0  Commission of Crime        1  Downtown West             73.0
# 3         29.0  Commission of Crime        1  Downtown West             73.0
# 4         28.0      Fled in Vehicle        1  Downtown West             73.0
#
#    community_id
# 0           2.0
# 1           9.0
# 2           3.0
# 3           3.0
# 4           3.0

# %% [markdown]
# ## Rearrange Fields To Match ERD

# %%
# Use double brackets and tic marks to rearrange fields and produce head of DF
rearranged_df = merged_df_x[['police_use_of_force_id','response_date',
                             'case_number','problem','subject_race',
                             'subject_sex', 'subject_age',
                             'subject_role', 'primary_offense',
                             'type_of_resistance', 'police_use_of_force_type',
                             'force_type_action', 'subject_injury', 
                             'neighborhood_id', 'neighborhood', 'precinct']]

rearranged_df.head()
# Out:
#    police_use_of_force_id       response_date case_number  \
# 0                11224233 2008-01-05 22:57:23   08-005343
# 1                11224234 2008-01-10 22:21:53   08-010291
# 2                11224235 2008-01-25 18:04:32   08-024156
# 3                11224236 2008-01-27 02:44:26   08-025819
# 4                11224237 2008-02-10 04:54:24   08-039928
#
#                     problem subject_race subject_sex  subject_age  \
# 0        Suspicious Person         Black        Male         29.0
# 1      Motor Vehicle Chase         White        Male         22.0
# 2              Disturbance         Black        Male         40.0
# 3              Disturbance         Black        Male         29.0
# 4  Traffic Law Enforcement         Black        Male         28.0
#
#   subject_role primary_offense   type_of_resistance police_use_of_force_type  \
# 0            A          FLEEFT         Fled on Foot             Bodily Force
# 1            A            FLEE      Fled in Vehicle             Bodily Force
# 2            A          DISCON  Commission of Crime                    Taser
# 3            A          DISCON  Commission of Crime        Chemical Irritant
# 4            A            FLEE      Fled in Vehicle             Bodily Force
#
#     force_type_action subject_injury  neighborhood_id   neighborhood precinct
# 0             Punches            Yes             45.0       Mckinley        4
# 1             Punches            Yes             25.0        Central        3
# 2        Firing Darts             No             73.0  Downtown West        1
# 3  Crowd Control Mace            NaN             73.0  Downtown West        1
# 4               Knees            Yes             73.0  Downtown West        1

# %% [markdown]
# ## Check The Type Of Data In subject_age field

# %%
# Check if subject_age field is int by use of .dtypes
rearranged_df.dtypes
# Out:
# police_use_of_force_id               int64
# response_date               datetime64[ns]
# case_number                         object
# problem                             object
# subject_race                        object
# subject_sex                         object
# subject_age                        float64
# subject_role                        object
# primary_offense                     object
# type_of_resistance                  object
# police_use_of_force_type            object
# force_type_action                   object
# subject_injury                      object
# neighborhood_id                    float64
# neighborhood                        object
# precinct                            object
# dtype: object

# %% [markdown]
# ## Change NaN(s) To Zero In subject_age Field To Allow For Conversion To Int

# %%
# Change all NaN(s) Within The subject_age field to 0 via fillna
rearranged_df["subject_age"].fillna("0", inplace = True)
# Out:
# C:\Users\npren\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
# Confirm NaN(s) have been changed to 0 by producing df
rearranged_df
# Out:
#        police_use_of_force_id       response_date              case_number  \
# 0                    11224233 2008-01-05 22:57:23                08-005343
# 1                    11224234 2008-01-10 22:21:53                08-010291
# 2                    11224235 2008-01-25 18:04:32                08-024156
# 3                    11224236 2008-01-27 02:44:26                08-025819
# 4                    11224237 2008-02-10 04:54:24                08-039928
# ...                       ...                 ...                      ...
# 30049                11254282 2020-01-01 00:00:00             20-Lynnhurst
# 30050                11254283 2012-01-01 00:00:00      12-St. Anthony East
# 30051                11254284 2019-01-01 00:00:00         19-Columbia Park
# 30052                11254285 2019-01-01 00:00:00               19-Kenwood
# 30053                11254286 2012-01-01 00:00:00  12-Cedar - Isles - Dean
#
#                         problem subject_race subject_sex subject_age  \
# 0            Suspicious Person         Black        Male          29
# 1          Motor Vehicle Chase         White        Male          22
# 2                  Disturbance         Black        Male          40
# 3                  Disturbance         Black        Male          29
# 4      Traffic Law Enforcement         Black        Male          28
# ...                         ...          ...         ...         ...
# 30049                       NaN          NaN         NaN           0
# 30050                       NaN          NaN         NaN           0
# 30051                       NaN          NaN         NaN           0
# 30052                       NaN          NaN         NaN           0
# 30053                       NaN          NaN         NaN           0
#
#       subject_role primary_offense   type_of_resistance  \
# 0                A          FLEEFT         Fled on Foot
# 1                A            FLEE      Fled in Vehicle
# 2                A          DISCON  Commission of Crime
# 3                A          DISCON  Commission of Crime
# 4                A            FLEE      Fled in Vehicle
# ...            ...             ...                  ...
# 30049          NaN             NaN                  NaN
# 30050          NaN             NaN                  NaN
# 30051          NaN             NaN                  NaN
# 30052          NaN             NaN                  NaN
# 30053          NaN             NaN                  NaN
#
#       police_use_of_force_type   force_type_action subject_injury  \
# 0                 Bodily Force             Punches            Yes
# 1                 Bodily Force             Punches            Yes
# 2                        Taser        Firing Darts             No
# 3            Chemical Irritant  Crowd Control Mace            NaN
# 4                 Bodily Force               Knees            Yes
# ...                        ...                 ...            ...
# 30049                      NaN                   0            NaN
# 30050                      NaN                   0            NaN
# 30051                      NaN                   0            NaN
# 30052                      NaN                   0            NaN
# 30053                      NaN                   0            NaN
#
#        neighborhood_id          neighborhood precinct
# 0                 45.0              Mckinley        4
# 1                 25.0               Central        3
# 2                 73.0         Downtown West        1
# 3                 73.0         Downtown West        1
# 4                 73.0         Downtown West        1
# ...                ...                   ...      ...
# 30049              7.0             Lynnhurst      NaN
# 30050             19.0       St Anthony East      NaN
# 30051             13.0              Columbia      NaN
# 30052             36.0               Kenwood      NaN
# 30053             33.0  Cedar - Isles - Dean      NaN
#
# [30054 rows x 16 columns]

# %% [markdown]
# ## Convert subject_age Field To int64 From float64

# %%
# Convert subject_age field to int64 via astype function 
rearranged_df['subject_age'] = rearranged_df['subject_age'].astype(np.int64)
# Out:
# C:\Users\npren\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Confirm task from cell above was completed via .dtypes
rearranged_df.dtypes
# Out:
# police_use_of_force_id               int64
# response_date               datetime64[ns]
# case_number                         object
# problem                             object
# subject_race                        object
# subject_sex                         object
# subject_age                          int64
# subject_role                        object
# primary_offense                     object
# type_of_resistance                  object
# police_use_of_force_type            object
# force_type_action                   object
# subject_injury                      object
# neighborhood_id                    float64
# neighborhood                        object
# precinct                            object
# dtype: object

# %% [markdown]
# ## Change NaN(s) To Zero In neighborhood_id Field To Allow For Conversion To Int

# %%
# Change all NaN(s) Within The neighborhood_id field to 0 via fillna
rearranged_df["neighborhood_id"].fillna("0", inplace = True)
# Out:
# C:\Users\npren\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
# Confirm NaN(s) have been changed to 0 by producing df
rearranged_df
# Out:
#        police_use_of_force_id       response_date              case_number  \
# 0                    11224233 2008-01-05 22:57:23                08-005343
# 1                    11224234 2008-01-10 22:21:53                08-010291
# 2                    11224235 2008-01-25 18:04:32                08-024156
# 3                    11224236 2008-01-27 02:44:26                08-025819
# 4                    11224237 2008-02-10 04:54:24                08-039928
# ...                       ...                 ...                      ...
# 30049                11254282 2020-01-01 00:00:00             20-Lynnhurst
# 30050                11254283 2012-01-01 00:00:00      12-St. Anthony East
# 30051                11254284 2019-01-01 00:00:00         19-Columbia Park
# 30052                11254285 2019-01-01 00:00:00               19-Kenwood
# 30053                11254286 2012-01-01 00:00:00  12-Cedar - Isles - Dean
#
#                         problem subject_race subject_sex  subject_age  \
# 0            Suspicious Person         Black        Male           29
# 1          Motor Vehicle Chase         White        Male           22
# 2                  Disturbance         Black        Male           40
# 3                  Disturbance         Black        Male           29
# 4      Traffic Law Enforcement         Black        Male           28
# ...                         ...          ...         ...          ...
# 30049                       NaN          NaN         NaN            0
# 30050                       NaN          NaN         NaN            0
# 30051                       NaN          NaN         NaN            0
# 30052                       NaN          NaN         NaN            0
# 30053                       NaN          NaN         NaN            0
#
#       subject_role primary_offense   type_of_resistance  \
# 0                A          FLEEFT         Fled on Foot
# 1                A            FLEE      Fled in Vehicle
# 2                A          DISCON  Commission of Crime
# 3                A          DISCON  Commission of Crime
# 4                A            FLEE      Fled in Vehicle
# ...            ...             ...                  ...
# 30049          NaN             NaN                  NaN
# 30050          NaN             NaN                  NaN
# 30051          NaN             NaN                  NaN
# 30052          NaN             NaN                  NaN
# 30053          NaN             NaN                  NaN
#
#       police_use_of_force_type   force_type_action subject_injury  \
# 0                 Bodily Force             Punches            Yes
# 1                 Bodily Force             Punches            Yes
# 2                        Taser        Firing Darts             No
# 3            Chemical Irritant  Crowd Control Mace            NaN
# 4                 Bodily Force               Knees            Yes
# ...                        ...                 ...            ...
# 30049                      NaN                   0            NaN
# 30050                      NaN                   0            NaN
# 30051                      NaN                   0            NaN
# 30052                      NaN                   0            NaN
# 30053                      NaN                   0            NaN
#
#       neighborhood_id          neighborhood precinct
# 0                  45              Mckinley        4
# 1                  25               Central        3
# 2                  73         Downtown West        1
# 3                  73         Downtown West        1
# 4                  73         Downtown West        1
# ...               ...                   ...      ...
# 30049               7             Lynnhurst      NaN
# 30050              19       St Anthony East      NaN
# 30051              13              Columbia      NaN
# 30052              36               Kenwood      NaN
# 30053              33  Cedar - Isles - Dean      NaN
#
# [30054 rows x 16 columns]

# %% [markdown]
# ## Set Index To police_use_of_force_id Field

# %%
# Use .set_index to change the index of the df
rearranged_df.set_index('police_use_of_force_id', inplace=True)

# %%
# Verify change was made by calling df
rearranged_df
# Out:
#                              response_date              case_number  \
# police_use_of_force_id
# 11224233               2008-01-05 22:57:23                08-005343
# 11224234               2008-01-10 22:21:53                08-010291
# 11224235               2008-01-25 18:04:32                08-024156
# 11224236               2008-01-27 02:44:26                08-025819
# 11224237               2008-02-10 04:54:24                08-039928
# ...                                    ...                      ...
# 11254282               2020-01-01 00:00:00             20-Lynnhurst
# 11254283               2012-01-01 00:00:00      12-St. Anthony East
# 11254284               2019-01-01 00:00:00         19-Columbia Park
# 11254285               2019-01-01 00:00:00               19-Kenwood
# 11254286               2012-01-01 00:00:00  12-Cedar - Isles - Dean
#
#                                          problem subject_race subject_sex  \
# police_use_of_force_id
# 11224233                      Suspicious Person         Black        Male
# 11224234                    Motor Vehicle Chase         White        Male
# 11224235                            Disturbance         Black        Male
# 11224236                            Disturbance         Black        Male
# 11224237                Traffic Law Enforcement         Black        Male
# ...                                          ...          ...         ...
# 11254282                                     NaN          NaN         NaN
# 11254283                                     NaN          NaN         NaN
# 11254284                                     NaN          NaN         NaN
# 11254285                                     NaN          NaN         NaN
# 11254286                                     NaN          NaN         NaN
#
#                         subject_age subject_role primary_offense  \
# police_use_of_force_id
# 11224233                         29            A          FLEEFT
# 11224234                         22            A            FLEE
# 11224235                         40            A          DISCON
# 11224236                         29            A          DISCON
# 11224237                         28            A            FLEE
# ...                             ...          ...             ...
# 11254282                          0          NaN             NaN
# 11254283                          0          NaN             NaN
# 11254284                          0          NaN             NaN
# 11254285                          0          NaN             NaN
# 11254286                          0          NaN             NaN
#
#                          type_of_resistance police_use_of_force_type  \
# police_use_of_force_id
# 11224233                       Fled on Foot             Bodily Force
# 11224234                    Fled in Vehicle             Bodily Force
# 11224235                Commission of Crime                    Taser
# 11224236                Commission of Crime        Chemical Irritant
# 11224237                    Fled in Vehicle             Bodily Force
# ...                                     ...                      ...
# 11254282                                NaN                      NaN
# 11254283                                NaN                      NaN
# 11254284                                NaN                      NaN
# 11254285                                NaN                      NaN
# 11254286                                NaN                      NaN
#
#                          force_type_action subject_injury neighborhood_id  \
# police_use_of_force_id
# 11224233                           Punches            Yes              45
# 11224234                           Punches            Yes              25
# 11224235                      Firing Darts             No              73
# 11224236                Crowd Control Mace            NaN              73
# 11224237                             Knees            Yes              73
# ...                                    ...            ...             ...
# 11254282                                 0            NaN               7
# 11254283                                 0            NaN              19
# 11254284                                 0            NaN              13
# 11254285                                 0            NaN              36
# 11254286                                 0            NaN              33
#
#                                 neighborhood precinct
# police_use_of_force_id
# 11224233                            Mckinley        4
# 11224234                             Central        3
# 11224235                       Downtown West        1
# 11224236                       Downtown West        1
# 11224237                       Downtown West        1
# ...                                      ...      ...
# 11254282                           Lynnhurst      NaN
# 11254283                     St Anthony East      NaN
# 11254284                            Columbia      NaN
# 11254285                             Kenwood      NaN
# 11254286                Cedar - Isles - Dean      NaN
#
# [30054 rows x 15 columns]

# %% [markdown]
# ## Convert neighborhood_id Field To int64 From float64

# %%
# Convert neighborhood_id field to int64 via astype function
rearranged_df['neighborhood_id'] = rearranged_df['neighborhood_id'].astype(np.int64)
# Out:
# C:\Users\npren\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Check if neighborhood_id field is int64
rearranged_df.dtypes
# Out:
# response_date               datetime64[ns]
# case_number                         object
# problem                             object
# subject_race                        object
# subject_sex                         object
# subject_age                          int64
# subject_role                        object
# primary_offense                     object
# type_of_resistance                  object
# police_use_of_force_type            object
# force_type_action                   object
# subject_injury                      object
# neighborhood_id                      int64
# neighborhood                        object
# precinct                            object
# dtype: object

# %% [markdown]
# ## Rename Final DF

# %%
# Rename final df to something clearer
police_use_of_force_final_df = rearranged_df

# %% [markdown]
# ## Export Newest DF As CSV To target_files Folder

# %%
# Export useing to_csv function
police_use_of_force_final_df.to_csv("target_files/MLS_Police_Use_Of_Force_Cleaned_Data.csv", index=False, header=True)

# %% [markdown]
# ## Load police_use_of_force_final_df Data To Postgres Table

# %%
# Append cleaned data to the existing table in Postgres
police_use_of_force_final_df.to_sql('Group_Project', engine,if_exists='append')
